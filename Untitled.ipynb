# %%
`print("hello")
# Out:
#   Cell In[1], line 1
#     `print("hello")
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 data = np.random.randn(1000)
#       3 data.mean(), data.std()
#
# ModuleNotFoundError: No module named 'numpy'

# %%
1+1
# Out:
# 2

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a+b
#
# NameError: name 'a' is not defined

# %%
"a"+"b"
# Out:
# 'ab'

# %%
print(2)
# Out:
# 2

# %%
print("hello")
# Out:
# hello

# %%
# %timeit np.random.randn(10000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_ipython().run_line_magic('timeit', 'np.random.randn(10000)')
#
# File <magic-timeit>:1, in inner(_it, _timer)
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# NameError: name 'np' is not defined

# %%
1+1
# Out:
# 2

# %%
# %%time
model.fit(X_train, y_train, epochs=10)
# Out:
# CPU times: user 7 μs, sys: 2 μs, total: 9 μs
# Wall time: 11.2 μs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'model.fit(X_train, y_train, epochs=10)\n')
#
# File <timed eval>:1
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# NameError: name 'model' is not defined

# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(-0.02567999397875492), np.float64(1.0307015461457916))

# %%
# %timeit np.random.randn(10000)
# Out:
# 161 μs ± 9.41 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit np.random.randn(10000)
# Out:
# 162 μs ± 10.3 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%time
model.fit(X_train, y_train, epochs=10)
# Out:
# CPU times: user 6 μs, sys: 0 ns, total: 6 μs
# Wall time: 8.34 μs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'model.fit(X_train, y_train, epochs=10)\n')
#
# File <timed eval>:1
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# NameError: name 'model' is not defined
