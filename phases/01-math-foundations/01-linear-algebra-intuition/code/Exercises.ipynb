# %%
from vectors import Vector

# %%
a = Vector([[0, 0], [1, 1]])

# %%
a.angle_between()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a.angle_between()
#
# TypeError: Vector.angle_between() missing 1 required positional argument: 'other'
